# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = ''

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
sample = requests.request('GET', 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?api_key='+API_KEY+'&start_date=2020-11-25&end_date=2020-11-25')

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
print(dict(sample.json()))
# Out:
# {'dataset': {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-12-01T14:48:09.907Z', 'newest_available_date': '2020-12-01', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2020-11-25', 'end_date': '2020-11-25', 'data': [['2020-11-25', 111.4, 111.4, 110.1, 110.1, None, 294.0, 32435.8, None, None, None]], 'collapse': None, 'order': None, 'database_id': 6129}}

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
get_url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json'
start_date = '2017-01-01'
end_date = '2017-12-31'

_2017 = requests.request('GET', get_url+'?api_key='+API_KEY+'&start_date='+start_date+'&end_date='+end_date)

# %%
dict_2017 = dict(_2017.json())
data_2017 = {}

# %%
for value in dict_2017['dataset']['data']:
    v_date = value[0]
    v_open = value[1]
    v_high = value[2]
    v_low = value[3]
    v_close = value[4]
    v_volume = value[6]
    data_2017[v_date] = {'open': v_open, 'high': v_high, 'low': v_low, 'close': v_close, 'volume': v_volume}
    

data_2017
# Out:
# {'2017-12-29': {'open': 51.76,
#   'high': 51.94,
#   'low': 51.45,
#   'close': 51.76,
#   'volume': 34640.0},
#  '2017-12-28': {'open': 51.65,
#   'high': 51.82,
#   'low': 51.43,
#   'close': 51.6,
#   'volume': 40660.0},
#  '2017-12-27': {'open': 51.45,
#   'high': 51.89,
#   'low': 50.76,
#   'close': 51.82,
#   'volume': 57452.0},
#  '2017-12-22': {'open': 51.05,
#   'high': 51.5,
#   'low': 50.92,
#   'close': 51.32,
#   'volume': 71165.0},
#  '2017-12-21': {'open': 51.16,
#   'high': 51.52,
#   'low': 50.9,
#   'close': 51.4,
#   'volume': 120649.0},
#  '2017-12-20': {'open': 51.88,
#   'high': 52.04,
#   'low': 51.2,
#   'close': 51.27,
#   'volume': 50587.0},
#  '2017-12-19': {'open': 52.73,
#   'high': 52.73,
#   'low': 51.07,
#   'close': 51.66,
#   'volume': 137313.0},
#  '2017-12-18': {'open': 52.37,
#   'high': 52.75,
#   'low': 51.61,
#   'close': 52.62,
#   'volume': 129733.0},
#  '2017-12-15': {'open': 52.7,
#   'high': 52.7,
#   'low': 51.64,
#   'close': 52.01,
# ...

# %%
#Calculate what the highest and lowest opening prices were for the stock in this period.
open_2017 = {x[0]: x[1]['open'] for x in data_2017.items() if x[1]['open'] != None}

open_2017_max = max(open_2017.items(), key=lambda x: x[1])
print('Highest Opening: '+str(open_2017_max[1])+' on '+str(open_2017_max[0]))
# Out:
# Highest Opening: 53.11 on 2017-12-14

# %%
open_2017_min = min(open_2017.items(), key=lambda x: x[1])
print('Lowest Opening: '+str(open_2017_min[1])+' on '+str(open_2017_min[0]))
# Out:
# Lowest Opening: 34.0 on 2017-01-24

# %%
#What was the largest change in any one day (based on High and Low price)?
daily_change_2017 = {x[0]: x[1]['high']-x[1]['low'] for x in data_2017.items() if x[1]['high'] != None and x[1]['low'] != None}
daily_change_2017_max = max(daily_change_2017.items(), key=lambda x: x[1])
print('Largest Change in one day: '+str(daily_change_2017_max[1])+' on '+str(daily_change_2017_max[0]))
# Out:
# Largest Change in one day: 2.8100000000000023 on 2017-05-11

# %%
#What was the average daily trading volume during this year?
volume_2017 = {x[1]['volume'] for x in data_2017.items() if x[1]['volume'] != None}
volume_2017_avg = sum(volume_2017)/len(volume_2017)
print('Average Daily Volume: '+str(volume_2017_avg))
# Out:
# Average Daily Volume: 89221.896

# %%
# What was the largest change between any two days (based on Closing Price)?
two_day_change_2017 = {}
list_2017 = list(dict_2017.items())[0][1]['data']
key = 0
while key < len(list_2017)-1:
    curr = key
    prev = curr + 1
    two_day_change_2017[(list_2017[prev][0], list_2017[curr][0])] = list_2017[curr][4] - list_2017[prev][4]
    key += 1

two_day_change_2017_max = max(two_day_change_2017.items(), key=lambda x: x[1])
print('Largest Positive Change between two days: '+str(two_day_change_2017_max[1])+' from '+two_day_change_2017_max[0][0]+' to '+two_day_change_2017_max[0][1])
# Out:
# Largest Positive Change between two days: 1.7199999999999989 from 2017-05-10 to 2017-05-11

# %%
two_day_change_2017_min = min(two_day_change_2017.items(), key=lambda x: x[1])
print('Largest Negative Change between two days: '+str(two_day_change_2017_min[1])+' from '+two_day_change_2017_min[0][0]+' to '+two_day_change_2017_min[0][1])
# Out:
# Largest Negative Change between two days: -2.559999999999995 from 2017-08-08 to 2017-08-09

# %% [markdown]
# # Answers

# %%
print('Highest Opening: '+str(open_2017_max[1])+' on '+str(open_2017_max[0]))
print('Lowest Opening: '+str(open_2017_min[1])+' on '+str(open_2017_min[0]))
print('Largest Change in one day: '+str(daily_change_2017_max[1])+' on '+str(daily_change_2017_max[0]))
print('Average Daily Volume: '+str(volume_2017_avg))
print('Largest Positive Change between two days: '+str(two_day_change_2017_max[1])+' from '+two_day_change_2017_max[0][0]+' to '+two_day_change_2017_max[0][1])
print('Largest Negative Change between two days: '+str(two_day_change_2017_min[1])+' from '+two_day_change_2017_min[0][0]+' to '+two_day_change_2017_min[0][1])
# Out:
# Highest Opening: 53.11 on 2017-12-14
# Lowest Opening: 34.0 on 2017-01-24
# Largest Change in one day: 2.8100000000000023 on 2017-05-11
# Average Daily Volume: 89221.896
# Largest Positive Change between two days: 1.7199999999999989 from 2017-05-10 to 2017-05-11
# Largest Negative Change between two days: -2.559999999999995 from 2017-08-08 to 2017-08-09
